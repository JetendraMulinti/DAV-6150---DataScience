# %% [markdown]
# # Team Members:
#
# Jetendra Mulinti, Goutham Vemula, Prajeeth Nakka

# %% [markdown]
# Introduction: Here, the problem we are trying create a clean a messy wine data by performing cleaning techniques.
#
# Steps we are following
# 1. Loading data
# 2. EDA
# 3. Data Cleaning
# 4. Post-Clean EDA (To see how our cleaning impacted)

# %%
### Import packages

import warnings
warnings.filterwarnings('ignore')
import pandas as pd
pd.options.display.max_columns = 999
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.backends.backend_pdf import PdfPages
import seaborn as sns
import os
import missingno as msno
from scipy import stats
from scipy.stats import yeojohnson

# %%
### load data from csv via github url

github_url = 'https://raw.githubusercontent.com/JetendraMulinti/DAV-6150---DataScience/main/M3%20Practical%20Challenge%20Cleaning%20a%20Messy%20Data%20Set/M3_Data.csv'

wine_df = pd.read_csv(github_url)

#### delete columns unnamed:0 as it is default index column forms while saving csv file
del wine_df['Unnamed: 0']

wine_df.head(2)
# Out:
#    INDEX  TARGET  FixedAcidity  VolatileAcidity  CitricAcid  ResidualSugar  \
# 0      1       3           3.2             1.16        0.98           54.2
# 1      2       3           4.5             0.16        0.81           26.1
#
#    Chlorides  FreeSulfurDioxide  TotalSulfurDioxide  Density    pH  Sulphates  \
# 0      0.567                NaN               268.0  0.99280  3.33       0.59
# 1      0.425               15.0               327.0  1.02792  3.38       0.70
#
#    Alcohol  LabelAppeal  AcidIndex  STARS
# 0      9.9            0          8    2.0
# 1      NaN           -1          7    3.0

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
wine_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12795 entries, 0 to 12794
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   INDEX               12795 non-null  int64
#  1   TARGET              12795 non-null  int64
#  2   FixedAcidity        12795 non-null  float64
#  3   VolatileAcidity     12795 non-null  float64
#  4   CitricAcid          12795 non-null  float64
#  5   ResidualSugar       12179 non-null  float64
#  6   Chlorides           12157 non-null  float64
#  7   FreeSulfurDioxide   12148 non-null  float64
#  8   TotalSulfurDioxide  12113 non-null  float64
#  9   Density             12795 non-null  float64
#  10  pH                  12400 non-null  float64
#  11  Sulphates           11585 non-null  float64
#  12  Alcohol             12142 non-null  float64
#  13  LabelAppeal         12795 non-null  int64
#  14  AcidIndex           12795 non-null  int64
# ...

# %%
wine_df.describe()
# Out:
#               INDEX        TARGET  FixedAcidity  VolatileAcidity  \
# count  12795.000000  12795.000000  12795.000000     12795.000000
# mean    8069.980305      3.029074      8.063251         0.641086
# std     4656.905107      1.926368      4.996119         0.555614
# min        1.000000      0.000000      0.000000         0.000000
# 25%     4037.500000      2.000000      5.600000         0.250000
# 50%     8110.000000      3.000000      7.000000         0.410000
# 75%    12106.500000      4.000000      9.800000         0.910000
# max    16129.000000      8.000000     34.400000         3.680000
#
#          CitricAcid  ResidualSugar     Chlorides  FreeSulfurDioxide  \
# count  12795.000000   12179.000000  12157.000000       12148.000000
# mean       0.686315      23.367809      0.222559         106.679042
# std        0.606005      24.945667      0.234288         108.102694
# min        0.000000       0.000000      0.000000           0.000000
# ...

# %%
## Sitation: Help from chatgpt
###### Creating a function that gives univariate analysis on quantitative columns


def Hist_BoxPlotFunction(df, pdf_filename):
    """
    Saves histograms and box plots for all quantitative columns in the DataFrame to a single PDF file
    in the current working directory and displays the plots.
    
    Parameters:
    - df: pandas DataFrame.
    - pdf_filename: String. The filename for the PDF to be saved.
    """
    
    # Path for saving the PDF in the current working directory
    pdf_path = os.path.join(os.getcwd(), pdf_filename)
    
    quantitative_columns = df.select_dtypes(include=['float64', 'int64']).columns
    quantitative_columns = quantitative_columns.drop('INDEX', errors='ignore')  # Drop 'INDEX' if it exists
    
    with PdfPages(pdf_path) as pdf:
        for col in quantitative_columns:
            fig, axs = plt.subplots(1, 2, figsize=(12, 4))
            
            # Histogram
            sns.histplot(df[col], ax=axs[0], kde=True)
            axs[0].set_title(f'Histogram of {col}')
            
            # Box Plot
            sns.boxplot(x=df[col], ax=axs[1])
            axs[1].set_title(f'Box Plot of {col}')
            
            plt.tight_layout()
            pdf.savefig(fig)  # Save the figure into the PDF
            plt.show()  # Display the plot
            plt.close(fig)  # Close to free up memory

# %%
Hist_BoxPlotFunction(wine_df, "wine_df_quantVisuals.pdf")

# %%
### correlation of data

####### I am using correlation matrix for identifying independent columns to dependent columns

def plot_correlation_matrix(df):

    # Calculate the correlation matrix
    corr_matrix = df.corr()
    
    # Generate a mask for the upper triangle
    mask = np.triu(np.ones_like(corr_matrix, dtype=bool))

    # Set up the matplotlib figure
    f, ax = plt.subplots(figsize=(15, 15))

    # Generate a custom diverging colormap
    cmap = sns.diverging_palette(230, 20, as_cmap=True)

    # Draw the heatmap with the mask and correct aspect ratio
    sns.heatmap(corr_matrix, mask=mask, cmap=cmap, vmax=.3, center=0,
                square=True, linewidths=.5, cbar_kws={"shrink": .5}, annot=True)

    plt.show()

# %%
plot_correlation_matrix(wine_df)

# %%
### we are not using scatter plots as we are seeing low correlation scores, so we might skip these.

# %% [markdown]
# ### Even though we can see the null values from info session & labelAppeal has -ve values in describe, will do EDA atleast Univariate analysis & move the data cleaning for more understanding,
#
# ### As all columns are in numeric we wont need to cross check for any other values, but Stars & Label Appeal are categorical variables.

# %% [markdown]
# Density histogram looks like a normally distributed data, but it has outliers on both ends.
#
# Target column tells no of cases sold, which tells 4,0,3 cases are sold most.
#
# Coming to skewness of the data Most columns has outliers & Right skewed data

# %% [markdown]
# # Data Cleaning

# %%
#### lets % the missing values

round(wine_df.isnull().sum() / len(wine_df) * 100,2)
# Out:
# INDEX                  0.00
# TARGET                 0.00
# FixedAcidity           0.00
# VolatileAcidity        0.00
# CitricAcid             0.00
# ResidualSugar          4.81
# Chlorides              4.99
# FreeSulfurDioxide      5.06
# TotalSulfurDioxide     5.33
# Density                0.00
# pH                     3.09
# Sulphates              9.46
# Alcohol                5.10
# LabelAppeal            0.00
# AcidIndex              0.00
# STARS                 26.25
# dtype: float64

# %%
### Lets Plot it

msno.bar(wine_df)
# Out:
# <AxesSubplot: >

# %% [markdown]
# From this plot we can say the missing values are not occured randomly but happened after 75 % of data is filled.

# %% [markdown]
# #### Imputating Missing Data
#
# 1. ResidualSugar - Right Skewed Distribution (Median Imputation)
# 2. Chlorides - Right Skewed Distribution (Median Imputation)
# 3. FreeSulfurDioxide - Right Skewed Distribution (Median Imputation)
# 4. TotalSulfurDioxide - Right Skewed Distribution (Median Imputation)
# 5. pH - Normal Distribution (Mean Imputation)
# 6. Sulphates - Right Skewed Distribution (Median Imputation)
# 7. Alcohol - Normal Distribution (Mean Imputation)
# 8. STARS - Median Imputation (For better approach we need to ask domain expertise also, as we have more missing values)

# %%
## Making a copy of original dataframe
wine_df_new = wine_df.copy(deep=True)

# %%
###### Median Imputation

ResidualSugar_Median = wine_df_new['ResidualSugar'].median()
Chlorides_Median = wine_df_new['Chlorides'].median()
FreeSulfurDioxide_Median = wine_df_new['FreeSulfurDioxide'].median()
TotalSulfurDioxide_Median = wine_df_new['TotalSulfurDioxide'].median()
Sulphates_Median = wine_df_new['Sulphates'].median()
Stars_Median = int(wine_df_new['STARS'].median())


wine_df_new['ResidualSugar'].fillna(ResidualSugar_Median, inplace=True)
wine_df_new['Chlorides'].fillna(Chlorides_Median, inplace=True)
wine_df_new['FreeSulfurDioxide'].fillna(FreeSulfurDioxide_Median, inplace=True)
wine_df_new['TotalSulfurDioxide'].fillna(TotalSulfurDioxide_Median, inplace=True)
wine_df_new['Sulphates'].fillna(Sulphates_Median, inplace=True)
wine_df_new['STARS'].fillna(Stars_Median, inplace=True)

# %%
###### Mean Imputation

pH_Mean = wine_df_new['pH'].mean()
Alcohol_Mean = wine_df_new['Alcohol'].mean()

wine_df_new['pH'].fillna(pH_Mean, inplace=True)
wine_df_new['Alcohol'].fillna(Alcohol_Mean, inplace=True)

# %%
#### change data Types (According to data description)

### Stars column (Generally int datatype)

wine_df_new['STARS'] = wine_df_new['STARS'].astype(int)

### As Label Appeal has -ve values also (Assuming this as -ve values are negative score, 0 neutral, +ve as +ve scores) 
### & its int datatype as we have only int values

wine_df_new['LabelAppeal'] = wine_df_new['LabelAppeal'].astype(int)

# %%
### Lets Plot it

msno.bar(wine_df_new)
# Out:
# <AxesSubplot: >

# %% [markdown]
# # Now we will deal with Outliers

# %%
## FixedAcidity - Right Skewed Distributed
## VolatileAcidity - Right Skewed Distributed
## CitricAcid - Right Skewed Distributed
## ResidualSugar - Right Skewed Distributed
## Chlorides - Right Skewed Distributed
## FreeSulfurDioxide - Right Skewed Distributed
## Sulphates - Right Skewed Distributed


## Density - Normally Distributed
## pH - Normally Distributed
## Alcohol - Normally Distributed

# %%
Hist_BoxPlotFunction(wine_df_new, "wine_df_quantVisuals_PostFillNa.pdf")

# %%
wine_df_new.describe()
# Out:
#               INDEX        TARGET  FixedAcidity  VolatileAcidity  \
# count  12795.000000  12795.000000  12795.000000     12795.000000
# mean    8069.980305      3.029074      8.063251         0.641086
# std     4656.905107      1.926368      4.996119         0.555614
# min        1.000000      0.000000      0.000000         0.000000
# 25%     4037.500000      2.000000      5.600000         0.250000
# 50%     8110.000000      3.000000      7.000000         0.410000
# 75%    12106.500000      4.000000      9.800000         0.910000
# max    16129.000000      8.000000     34.400000         3.680000
#
#          CitricAcid  ResidualSugar     Chlorides  FreeSulfurDioxide  \
# count  12795.000000   12795.000000  12795.000000       12795.000000
# mean       0.686315      22.863849      0.216348         104.116374
# std        0.606005      24.440673      0.229975         105.917566
# min        0.000000       0.000000      0.000000           0.000000
# ...

# %% [markdown]
# ### For Normally distributed columns outliers might be errors ( Capping (Winsorization))
# ### For skewed distributed data, outliers are common & represent important variations (Use Transformation)

# %%
#### Capping (For Notmally distributed data)
#### We considered lower_percentile, upper_percentile as default values. 

def cap_outliers(series, lower_percentile=0.05, upper_percentile=0.95):
    """
    Caps outliers in a pandas series to specified percentile thresholds.
    """
    quantiles = series.quantile([lower_percentile, upper_percentile])
    series_capped = series.clip(quantiles[lower_percentile], quantiles[upper_percentile])
    return series_capped



CappingColumns = ['pH', 'Alcohol','Density', 'AcidIndex']

# Applying the function to cap outliers in the dataset
for column in CappingColumns:
    wine_df_new[column] = cap_outliers(wine_df_new[column])

# %%
wine_df_new.describe()
# Out:
#               INDEX        TARGET  FixedAcidity  VolatileAcidity  \
# count  12795.000000  12795.000000  12795.000000     12795.000000
# mean    8069.980305      3.029074      8.063251         0.641086
# std     4656.905107      1.926368      4.996119         0.555614
# min        1.000000      0.000000      0.000000         0.000000
# 25%     4037.500000      2.000000      5.600000         0.250000
# 50%     8110.000000      3.000000      7.000000         0.410000
# 75%    12106.500000      4.000000      9.800000         0.910000
# max    16129.000000      8.000000     34.400000         3.680000
#
#          CitricAcid  ResidualSugar     Chlorides  FreeSulfurDioxide  \
# count  12795.000000   12795.000000  12795.000000       12795.000000
# mean       0.686315      22.863849      0.216348         104.116374
# std        0.606005      24.440673      0.229975         105.917566
# min        0.000000       0.000000      0.000000           0.000000
# ...

# %%
BoxCoxTransformationColumns = ['FixedAcidity','VolatileAcidity','CitricAcid', 'ResidualSugar',
                              'Chlorides','FreeSulfurDioxide','Sulphates']


BoxCoxTransformationColumns
# Out:
# ['FixedAcidity',
#  'VolatileAcidity',
#  'CitricAcid',
#  'ResidualSugar',
#  'Chlorides',
#  'FreeSulfurDioxide',
#  'Sulphates']

# %%
##########  BoxCoxFunction 

def BoxCoxFunction(df,Columns):

    # Apply Box-Cox transformation
    for column in Columns:
        # Ensure all data is positive (Box-Cox requires positive values)
        if df[column].min() >= 0:
            df[column], fitted_lambda = stats.boxcox(df[column])
        else:
            print(f"Column {column} contains non-positive values and cannot be transformed")

    return df

# %%
BoxCoxFunction(wine_df_new, BoxCoxTransformationColumns)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 BoxCoxFunction(wine_df_new, BoxCoxTransformationColumns)
#
# Cell In[23], line 9, in BoxCoxFunction(df, Columns)
#       6 for column in Columns:
#       7     # Ensure all data is positive (Box-Cox requires positive values)
#       8     if df[column].min() >= 0:
# ----> 9         df[column], fitted_lambda = stats.boxcox(df[column])
#      10     else:
#      11         print(f"Column {column} contains non-positive values and cannot be transformed")
#
# File ~\anaconda3\lib\site-packages\scipy\stats\_morestats.py:1090, in boxcox(x, lmbda, alpha, optimizer)
#    1087     raise ValueError("Data must not be constant.")
#    1089 if np.any(x <= 0):
# -> 1090     raise ValueError("Data must be positive.")
#    1092 # If lmbda=None, find the lmbda that maximizes the log-likelihood function.
# ...

# %% [markdown]
# #### As our values are also consists of 0, we can't use BoxCox Transformation, we want to use Yeo-Johnson transformation

# %%
##########  Yeo-Johnson transformation

def Yeo_Johnson(df,Columns):

    # Apply Yeo-Johnson transformation
    for column in Columns:
        
        try:
            # Apply the transformation and ignore the lambda value by using an underscore
            df[column], _ = yeojohnson(df[column])
        except:
            print("Issue")

    return df

# %%
wine_df_new_transformed = Yeo_Johnson(wine_df_new, BoxCoxTransformationColumns)
wine_df_new_transformed.head(2)
# Out:
#    INDEX  TARGET  FixedAcidity  VolatileAcidity  CitricAcid  ResidualSugar  \
# 0      1       3      1.931060         0.437620    0.439509       4.409387
# 1      2       3      2.432704         0.131759    0.402801       3.566113
#
#    Chlorides  FreeSulfurDioxide  TotalSulfurDioxide  Density    pH  Sulphates  \
# 0   0.201098           4.866846               268.0  0.99280  3.33   0.347265
# 1   0.183600           3.144934               327.0  1.02792  3.38   0.382085
#
#      Alcohol  LabelAppeal  AcidIndex  STARS
# 0   9.900000            0          8      2
# 1  10.523778           -1          7      3

# %%
Hist_BoxPlotFunction(wine_df_new_transformed, "wine_df_quantVisuals_PostTransformed.pdf")

# %% [markdown]
# #### From the above visuals we can say that we ahve suceeded in normalizing the data & capped the outliers, if we want we can use Yeo_Johnson transformation for normally distributed data

# %%
plot_correlation_matrix(wine_df_new_transformed)

# %% [raw]
# ### Conclusion:
#
# Here we perfomed the steps of EDA (Pre Data Cleaning), Data Cleaning (Imputating Missing values & Handling Outliers).
# 1. Imputing missing values
#     For Normal distributed data we use mean
#     For Skewed data we used medain
# 2. Handling outliers
#     For Normal distributed data we used Capping
#     For Skewed data first we tried yeojohnson transformation (first we tried Boxcox transformation, but it can't handle 0       values)
# 3. Post Data cleaning we performed EDA which tells data has been transformed from skewed to normally distributed.
# 4. By having normally distributed data, which will benefit in easier interpretation and prediction of model.
